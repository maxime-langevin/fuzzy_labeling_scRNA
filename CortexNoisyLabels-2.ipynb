# %%
from scvi.dataset import CortexDataset, CortexDatasetCustom
from scvi.models import SVAEC, UVAE
from scvi.inference import JointSemiSupervisedVariationalInference, JointSemiSupervisedVariationalInferenceUncertain
# %matplotlib inline
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# # Corruption probabilities: [0.1, 0.4]

# %%
# Corrupted dataset to train
gene_dataset = CortexDatasetCustom(corruption_probabilities=[0.1, 0.4], additional_genes=100)
use_batches=False
use_cuda=True
# Out:
# File data/expression.bin already downloaded
# Preprocessing Cortex data
# Finished preprocessing Cortex data

# %%
svaec = SVAEC(gene_dataset.nb_genes, gene_dataset.n_batches, gene_dataset.n_labels)
infer = JointSemiSupervisedVariationalInference(svaec, gene_dataset, n_labelled_samples_per_class=10)
infer.train(n_epochs=150)
print(infer.accuracy('unlabelled'))
# Out:
# training: 100%|██████████| 150/150 [00:09<00:00, 15.74it/s]
# 0.7156549520766773

# %%
uvae = UVAE(gene_dataset.nb_genes, gene_dataset.n_batches, gene_dataset.n_labels)
infer = JointSemiSupervisedVariationalInferenceUncertain(uvae, gene_dataset, n_labelled_samples_per_class=10, classification_ratio=[2.3, 0.9])
infer.train(n_epochs=150)
infer.show_t_sne('all', color_by='labels')
print(infer.accuracy('unlabelled'))
# Out:
# training: 100%|██████████| 150/150 [00:10<00:00, 14.48it/s]
# 0.8019169329073482

# %%
# Uncorrupted dataset to test
new_gene_dataset = CortexDatasetCustom(corruption_probabilities=[0, 0], additional_genes=100)
# Out:
# File data/expression.bin already downloaded
# Preprocessing Cortex data
# Finished preprocessing Cortex data

# %%
infer = JointSemiSupervisedVariationalInference(svaec, new_gene_dataset, n_labelled_samples_per_class=1)
infer.train(n_epochs=1, lr=0)
print(infer.accuracy('unlabelled'))
# Out:
# training: 100%|██████████| 1/1 [00:00<00:00, 12.29it/s]
# 0.6555891238670695

# %%
infer = JointSemiSupervisedVariationalInferenceUncertain(uvae, new_gene_dataset, n_labelled_samples_per_class=10)
infer.train(n_epochs=1, lr=0)
print(infer.accuracy('unlabelled'))
infer.show_t_sne('unlabelled', color_by='labels')
# Out:
# training: 100%|██████████| 1/1 [00:00<00:00, 13.48it/s]
# 0.7188498402555911

# %% [markdown]
# # Corruption probabilities: [0.1, 0.25]

# %%
# Corrupted dataset to train
gene_dataset = CortexDatasetCustom(corruption_probabilities=[0.1, 0.25], additional_genes=100)
use_batches=False
use_cuda=True
# Out:
# File data/expression.bin already downloaded
# Preprocessing Cortex data
# Finished preprocessing Cortex data

# %%
svaec = SVAEC(gene_dataset.nb_genes, gene_dataset.n_batches, gene_dataset.n_labels)
infer = JointSemiSupervisedVariationalInference(svaec, gene_dataset, n_labelled_samples_per_class=10)
infer.train(n_epochs=150)
print(infer.accuracy('unlabelled'))
# Out:
# training: 100%|██████████| 150/150 [00:11<00:00, 13.13it/s]
# 0.7092651757188498

# %%
uvae = UVAE(gene_dataset.nb_genes, gene_dataset.n_batches, gene_dataset.n_labels)
infer = JointSemiSupervisedVariationalInferenceUncertain(uvae, gene_dataset, n_labelled_samples_per_class=10, classification_ratio=[2.3, 1.4])
infer.train(n_epochs=150)
infer.show_t_sne('all', color_by='labels')
print(infer.accuracy('unlabelled'))
# Out:
# training: 100%|██████████| 150/150 [00:12<00:00, 12.35it/s]
# 0.6964856230031949

# %%
# Uncorrupted dataset to test
new_gene_dataset = CortexDatasetCustom(corruption_probabilities=[0, 0], additional_genes=100)
# Out:
# File data/expression.bin already downloaded
# Preprocessing Cortex data
# Finished preprocessing Cortex data

# %%
infer = JointSemiSupervisedVariationalInference(svaec, new_gene_dataset, n_labelled_samples_per_class=1)
infer.train(n_epochs=1, lr=0)
print(infer.accuracy('unlabelled'))
# Out:
# training: 100%|██████████| 1/1 [00:00<00:00, 13.75it/s]
# 0.6737160120845922

# %%
infer = JointSemiSupervisedVariationalInferenceUncertain(uvae, new_gene_dataset, n_labelled_samples_per_class=1)
infer.train(n_epochs=1, lr=0)
print(infer.accuracy('unlabelled'))
#infer.show_t_sne('unlabelled', color_by='labels')
# Out:
# training: 100%|██████████| 1/1 [00:00<00:00, 12.71it/s]
# 0.7069486404833837

# %% [markdown]
# # Corruption probabilities: [0.1, 0.3]

# %%
# Corrupted dataset to train
gene_dataset = CortexDatasetCustom(corruption_probabilities=[0.1, 0.3], additional_genes=100)
use_batches=False
use_cuda=True
# Out:
# File data/expression.bin already downloaded
# Preprocessing Cortex data
# Finished preprocessing Cortex data

# %%
svaec = SVAEC(gene_dataset.nb_genes, gene_dataset.n_batches, gene_dataset.n_labels)
infer = JointSemiSupervisedVariationalInference(svaec, gene_dataset, n_labelled_samples_per_class=10)
infer.train(n_epochs=150)
print(infer.accuracy('unlabelled'))
# Out:
# training: 100%|██████████| 150/150 [00:09<00:00, 18.99it/s]
# 0.6134185303514377

# %%
uvae = UVAE(gene_dataset.nb_genes, gene_dataset.n_batches, gene_dataset.n_labels)
infer = JointSemiSupervisedVariationalInferenceUncertain(uvae, gene_dataset, n_labelled_samples_per_class=10, classification_ratio=[2.3, 1.2])
infer.train(n_epochs=150)
infer.show_t_sne('all', color_by='labels')
print(infer.accuracy('unlabelled'))
# Out:
# training: 100%|██████████| 150/150 [00:11<00:00, 16.46it/s]
# 0.7539936102236422

# %%
# Uncorrupted dataset to test
new_gene_dataset = CortexDatasetCustom(corruption_probabilities=[0, 0], additional_genes=100)
# Out:
# File data/expression.bin already downloaded
# Preprocessing Cortex data
# Finished preprocessing Cortex data

# %%
infer = JointSemiSupervisedVariationalInference(svaec, new_gene_dataset, n_labelled_samples_per_class=1)
infer.train(n_epochs=1, lr=0)
print(infer.accuracy('unlabelled'))
# Out:
# training: 100%|██████████| 1/1 [00:00<00:00, 11.35it/s]
# 0.6918429003021148

# %%
infer = JointSemiSupervisedVariationalInferenceUncertain(uvae, new_gene_dataset, n_labelled_samples_per_class=10)
infer.train(n_epochs=1, lr=0)
print(infer.accuracy('unlabelled'))
infer.show_t_sne('unlabelled', color_by='labels')
# Out:
# training: 100%|██████████| 1/1 [00:00<00:00, 12.90it/s]
# 0.7188498402555911

# %% [markdown]
# # Corruption probabilities: [0.2, 0.4]

# %%
# Corrupted dataset to train
gene_dataset = CortexDatasetCustom(corruption_probabilities=[0.2, 0.4], additional_genes=100)
use_batches=False
use_cuda=True
# Out:
# File data/expression.bin already downloaded
# Preprocessing Cortex data
# Finished preprocessing Cortex data

# %%
svaec = SVAEC(gene_dataset.nb_genes, gene_dataset.n_batches, gene_dataset.n_labels)
infer = JointSemiSupervisedVariationalInference(svaec, gene_dataset, n_labelled_samples_per_class=10)
infer.train(n_epochs=150)
print(infer.accuracy('unlabelled'))
# Out:
# training: 100%|██████████| 150/150 [00:10<00:00, 14.70it/s]
# 0.5718849840255591

# %%
uvae = UVAE(gene_dataset.nb_genes, gene_dataset.n_batches, gene_dataset.n_labels)
infer = JointSemiSupervisedVariationalInferenceUncertain(uvae, gene_dataset, n_labelled_samples_per_class=10, classification_ratio=[1.6, 0.9])
infer.train(n_epochs=150)
infer.show_t_sne('all', color_by='labels')
print(infer.accuracy('unlabelled'))
# Out:
# training: 100%|██████████| 150/150 [00:14<00:00, 16.43it/s]
# 0.6805111821086262

# %%
# Uncorrupted dataset to test
new_gene_dataset = CortexDatasetCustom(corruption_probabilities=[0, 0], additional_genes=100)
# Out:
# File data/expression.bin already downloaded
# Preprocessing Cortex data
# Finished preprocessing Cortex data

# %%
infer = JointSemiSupervisedVariationalInference(svaec, new_gene_dataset, n_labelled_samples_per_class=1)
infer.train(n_epochs=1, lr=0)
print(infer.accuracy('unlabelled'))
infer.show_t_sne('unlabelled', color_by='labels')
# Out:
# training: 100%|██████████| 1/1 [00:00<00:00, 13.19it/s]
# 0.2990936555891239

# %%
infer = JointSemiSupervisedVariationalInferenceUncertain(uvae, new_gene_dataset, n_labelled_samples_per_class=10)
infer.train(n_epochs=1, lr=0)
print(infer.accuracy('unlabelled'))
infer.show_t_sne('unlabelled', color_by='labels')
# Out:
# training: 100%|██████████| 1/1 [00:00<00:00, 12.87it/s]
# 0.7188498402555911

# %% [markdown]
# # More extensive results

# %%
# Corruption probabilities: [0.2, 0.1]

# Corrupted dataset to train
gene_dataset = CortexDatasetCustom(corruption_probabilities=[0.2, 0.1], additional_genes=100)
use_batches=False
use_cuda=True

svaec = SVAEC(gene_dataset.nb_genes, gene_dataset.n_batches, gene_dataset.n_labels)
infer = JointSemiSupervisedVariationalInference(svaec, gene_dataset, n_labelled_samples_per_class=10)
infer.train(n_epochs=150)
print(infer.accuracy('unlabelled'))

uvae = UVAE(gene_dataset.nb_genes, gene_dataset.n_batches, gene_dataset.n_labels)
infer = JointSemiSupervisedVariationalInferenceUncertain(uvae, gene_dataset, n_labelled_samples_per_class=10, classification_ratio=[4, 1])
infer.train(n_epochs=250)
infer.show_t_sne('all', color_by='labels')
print(infer.accuracy('unlabelled'))

# Uncorrupted dataset to test
new_gene_dataset = CortexDatasetCustom(corruption_probabilities=[0, 0], additional_genes=100)

infer = JointSemiSupervisedVariationalInference(svaec, new_gene_dataset, n_labelled_samples_per_class=1)
infer.train(n_epochs=1, lr=0)
print(infer.accuracy('unlabelled'))
infer.show_t_sne('unlabelled', color_by='labels')

infer = JointSemiSupervisedVariationalInferenceUncertain(uvae, new_gene_dataset, n_labelled_samples_per_class=10)
infer.train(n_epochs=1, lr=0)
print(infer.accuracy('unlabelled'))
infer.show_t_sne('unlabelled', color_by='labels')
# Out:
# File data/expression.bin already downloaded
# Preprocessing Cortex data
# Finished preprocessing Cortex data
# training: 100%|██████████| 150/150 [00:09<00:00, 15.55it/s]
# 0.7220447284345048
# training: 100%|██████████| 250/250 [00:17<00:00, 14.65it/s]
# 0.6134185303514377
# File data/expression.bin already downloaded
# Preprocessing Cortex data
# Finished preprocessing Cortex data
# training: 100%|██████████| 1/1 [00:00<00:00, 13.75it/s]
# 0.6314199395770392
# training: 100%|██████████| 1/1 [00:00<00:00, 14.29it/s]
# 0.7188498402555911

# %%
# Corruption probabilities: [0.2, 0.2]

# Corrupted dataset to train
gene_dataset = CortexDatasetCustom(corruption_probabilities=[0.2, 0.2], additional_genes=100)
use_batches=False
use_cuda=True

svaec = SVAEC(gene_dataset.nb_genes, gene_dataset.n_batches, gene_dataset.n_labels)
infer = JointSemiSupervisedVariationalInference(svaec, gene_dataset, n_labelled_samples_per_class=10)
infer.train(n_epochs=250)
print(infer.accuracy('unlabelled'))

uvae = UVAE(gene_dataset.nb_genes, gene_dataset.n_batches, gene_dataset.n_labels)
infer = JointSemiSupervisedVariationalInferenceUncertain(uvae, gene_dataset, n_labelled_samples_per_class=10, classification_ratio=[3, 1])
infer.train(n_epochs=250)
#infer.show_t_sne('all', color_by='labels')
print(infer.accuracy('unlabelled'))

# Uncorrupted dataset to test
new_gene_dataset = CortexDatasetCustom(corruption_probabilities=[0, 0], additional_genes=100)

infer = JointSemiSupervisedVariationalInference(svaec, new_gene_dataset, n_labelled_samples_per_class=1)
infer.train(n_epochs=1, lr=0)
print(infer.accuracy('all'))
#infer.show_t_sne('unlabelled', color_by='labels')

infer = JointSemiSupervisedVariationalInferenceUncertain(uvae, new_gene_dataset, n_labelled_samples_per_class=10)
infer.train(n_epochs=1, lr=0)
print(infer.accuracy('all'))
#infer.show_t_sne('unlabelled', color_by='labels')
# Out:
# File data/expression.bin already downloaded
# Preprocessing Cortex data
# Finished preprocessing Cortex data
# training: 100%|██████████| 250/250 [00:16<00:00, 19.39it/s]
# 0.7028753993610224
# training: 100%|██████████| 250/250 [00:17<00:00, 14.55it/s]
# 0.6357827476038339
# File data/expression.bin already downloaded
# Preprocessing Cortex data
# Finished preprocessing Cortex data
# training: 100%|██████████| 1/1 [00:00<00:00, 12.24it/s]
# 0.7057057057057057
# training: 100%|██████████| 1/1 [00:00<00:00, 12.37it/s]
# 0.7057057057057057

# %%
# Corruption probabilities: [0.2, 0.15]

# Corrupted dataset to train
gene_dataset = CortexDatasetCustom(corruption_probabilities=[0.2, 0.15], additional_genes=100)
use_batches=False
use_cuda=True

svaec = SVAEC(gene_dataset.nb_genes, gene_dataset.n_batches, gene_dataset.n_labels)
infer = JointSemiSupervisedVariationalInference(svaec, gene_dataset, n_labelled_samples_per_class=10)
infer.train(n_epochs=100)
print(infer.accuracy('unlabelled'))

uvae = UVAE(gene_dataset.nb_genes, gene_dataset.n_batches, gene_dataset.n_labels)
infer = JointSemiSupervisedVariationalInferenceUncertain(uvae, gene_dataset, n_labelled_samples_per_class=10, classification_ratio=[2, 1])
infer.train(n_epochs=300)
#infer.show_t_sne('all', color_by='labels')
print(infer.accuracy('unlabelled'))

# Uncorrupted dataset to test
new_gene_dataset = CortexDatasetCustom(corruption_probabilities=[0, 0], additional_genes=100)

infer = JointSemiSupervisedVariationalInference(svaec, new_gene_dataset, n_labelled_samples_per_class=1)
infer.train(n_epochs=1, lr=0)
print(infer.accuracy('unlabelled'))
#infer.show_t_sne('unlabelled', color_by='labels')

infer = JointSemiSupervisedVariationalInferenceUncertain(uvae, new_gene_dataset, n_labelled_samples_per_class=10)
infer.train(n_epochs=1, lr=0)
print(infer.accuracy('unlabelled'))
#infer.show_t_sne('unlabelled', color_by='labels')
# Out:
# File data/expression.bin already downloaded
# Preprocessing Cortex data
# Finished preprocessing Cortex data
# training: 100%|██████████| 100/100 [00:06<00:00, 15.76it/s]
# 0.6805111821086262
# training: 100%|██████████| 300/300 [00:21<00:00, 19.15it/s]
# 0.597444089456869
# File data/expression.bin already downloaded
# Preprocessing Cortex data
# Finished preprocessing Cortex data
# training: 100%|██████████| 1/1 [00:00<00:00, 15.34it/s]
# 0.6132930513595166
# training: 100%|██████████| 1/1 [00:00<00:00, 14.14it/s]
# 0.7188498402555911

# %%
# Corruption probabilities: [0.2, 0.25]

# Corrupted dataset to train
gene_dataset = CortexDatasetCustom(corruption_probabilities=[0.2, 0.25], additional_genes=100)
use_batches=False
use_cuda=True

svaec = SVAEC(gene_dataset.nb_genes, gene_dataset.n_batches, gene_dataset.n_labels)
infer = JointSemiSupervisedVariationalInference(svaec, gene_dataset, n_labelled_samples_per_class=10)
infer.train(n_epochs=150)
print(infer.accuracy('unlabelled'))

uvae = UVAE(gene_dataset.nb_genes, gene_dataset.n_batches, gene_dataset.n_labels)
infer = JointSemiSupervisedVariationalInferenceUncertain(uvae, gene_dataset, n_labelled_samples_per_class=10, classification_ratio=[1.6, 1.2])
infer.train(n_epochs=150)
infer.show_t_sne('all', color_by='labels')
print(infer.accuracy('unlabelled'))

# Uncorrupted dataset to test
new_gene_dataset = CortexDatasetCustom(corruption_probabilities=[0, 0], additional_genes=100)

infer = JointSemiSupervisedVariationalInference(svaec, new_gene_dataset, n_labelled_samples_per_class=1)
infer.train(n_epochs=1, lr=0)
print(infer.accuracy('unlabelled'))
infer.show_t_sne('unlabelled', color_by='labels')

infer = JointSemiSupervisedVariationalInferenceUncertain(uvae, new_gene_dataset, n_labelled_samples_per_class=10)
infer.train(n_epochs=1, lr=0)
print(infer.accuracy('unlabelled'))
infer.show_t_sne('unlabelled', color_by='labels')
# Out:
# File data/expression.bin already downloaded
# Preprocessing Cortex data
# Finished preprocessing Cortex data
# training: 100%|██████████| 150/150 [00:11<00:00, 13.02it/s]
# 0.6293929712460063
# training: 100%|██████████| 150/150 [00:12<00:00, 18.04it/s]
# 0.7060702875399361
# File data/expression.bin already downloaded
# Preprocessing Cortex data
# Finished preprocessing Cortex data
# training: 100%|██████████| 1/1 [00:00<00:00, 14.80it/s]
# 0.716012084592145
# training: 100%|██████████| 1/1 [00:00<00:00, 13.83it/s]
# 0.7188498402555911

# %%
# Corruption probabilities: [0.2, 0.3]

# Corrupted dataset to train
gene_dataset = CortexDatasetCustom(corruption_probabilities=[0.2, 0.3], additional_genes=100)
use_batches=False
use_cuda=True

svaec = SVAEC(gene_dataset.nb_genes, gene_dataset.n_batches, gene_dataset.n_labels)
infer = JointSemiSupervisedVariationalInference(svaec, gene_dataset, n_labelled_samples_per_class=10)
infer.train(n_epochs=150)
print(infer.accuracy('unlabelled'))

uvae = UVAE(gene_dataset.nb_genes, gene_dataset.n_batches, gene_dataset.n_labels)
infer = JointSemiSupervisedVariationalInferenceUncertain(uvae, gene_dataset, n_labelled_samples_per_class=10, classification_ratio=[1.6, 1])
infer.train(n_epochs=150)
infer.show_t_sne('all', color_by='labels')
print(infer.accuracy('unlabelled'))

# Uncorrupted dataset to test
new_gene_dataset = CortexDatasetCustom(corruption_probabilities=[0, 0], additional_genes=100)

infer = JointSemiSupervisedVariationalInference(svaec, new_gene_dataset, n_labelled_samples_per_class=1)
infer.train(n_epochs=1, lr=0)
print(infer.accuracy('unlabelled'))
infer.show_t_sne('unlabelled', color_by='labels')

infer = JointSemiSupervisedVariationalInferenceUncertain(uvae, new_gene_dataset, n_labelled_samples_per_class=10)
infer.train(n_epochs=1, lr=0)
print(infer.accuracy('unlabelled'))
infer.show_t_sne('unlabelled', color_by='labels')
# Out:
# File data/expression.bin already downloaded
# Preprocessing Cortex data
# Finished preprocessing Cortex data
# training: 100%|██████████| 150/150 [00:12<00:00, 19.73it/s]
# 0.7124600638977636
# training: 100%|██████████| 150/150 [00:12<00:00, 19.19it/s]
# 0.6485623003194888
# File data/expression.bin already downloaded
# Preprocessing Cortex data
# Finished preprocessing Cortex data
# training: 100%|██████████| 1/1 [00:00<00:00, 12.27it/s]
# 0.7522658610271903
# training: 100%|██████████| 1/1 [00:00<00:00, 13.17it/s]
# 0.7188498402555911

# %%
# Corruption probabilities: [0.2, 0.35]

# Corrupted dataset to train
gene_dataset = CortexDatasetCustom(corruption_probabilities=[0.2, 0.35], additional_genes=100)
use_batches=False
use_cuda=True

svaec = SVAEC(gene_dataset.nb_genes, gene_dataset.n_batches, gene_dataset.n_labels)
infer = JointSemiSupervisedVariationalInference(svaec, gene_dataset, n_labelled_samples_per_class=10)
infer.train(n_epochs=150)
print(infer.accuracy('unlabelled'))

uvae = UVAE(gene_dataset.nb_genes, gene_dataset.n_batches, gene_dataset.n_labels)
infer = JointSemiSupervisedVariationalInferenceUncertain(uvae, gene_dataset, n_labelled_samples_per_class=10, classification_ratio=[1.6, 0.95])
infer.train(n_epochs=150)
infer.show_t_sne('all', color_by='labels')
print(infer.accuracy('unlabelled'))

# Uncorrupted dataset to test
new_gene_dataset = CortexDatasetCustom(corruption_probabilities=[0, 0], additional_genes=100)

infer = JointSemiSupervisedVariationalInference(svaec, new_gene_dataset, n_labelled_samples_per_class=1)
infer.train(n_epochs=1, lr=0)
print(infer.accuracy('unlabelled'))
infer.show_t_sne('unlabelled', color_by='labels')

infer = JointSemiSupervisedVariationalInferenceUncertain(uvae, new_gene_dataset, n_labelled_samples_per_class=10)
infer.train(n_epochs=1, lr=0)
print(infer.accuracy('unlabelled'))
infer.show_t_sne('unlabelled', color_by='labels')
# Out:
# File data/expression.bin already downloaded
# Preprocessing Cortex data
# Finished preprocessing Cortex data
# training: 100%|██████████| 150/150 [00:12<00:00, 19.74it/s]
# 0.5431309904153354
# training: 100%|██████████| 150/150 [00:12<00:00, 18.99it/s]
# 0.670926517571885
# File data/expression.bin already downloaded
# Preprocessing Cortex data
# Finished preprocessing Cortex data
# training: 100%|██████████| 1/1 [00:00<00:00, 11.54it/s]
# 0.6978851963746223
# training: 100%|██████████| 1/1 [00:00<00:00, 13.90it/s]
# 0.7188498402555911

# %%
# Corruption probabilities: [0.2, 0.4]

# Corrupted dataset to train
gene_dataset = CortexDatasetCustom(corruption_probabilities=[0.2, 0.4], additional_genes=100)
use_batches=False
use_cuda=True

svaec = SVAEC(gene_dataset.nb_genes, gene_dataset.n_batches, gene_dataset.n_labels)
infer = JointSemiSupervisedVariationalInference(svaec, gene_dataset, n_labelled_samples_per_class=10)
infer.train(n_epochs=150)
print(infer.accuracy('unlabelled'))

uvae = UVAE(gene_dataset.nb_genes, gene_dataset.n_batches, gene_dataset.n_labels)
infer = JointSemiSupervisedVariationalInferenceUncertain(uvae, gene_dataset, n_labelled_samples_per_class=10, classification_ratio=[1.6, 0.9])
infer.train(n_epochs=150)
infer.show_t_sne('all', color_by='labels')
print(infer.accuracy('unlabelled'))

# Uncorrupted dataset to test
new_gene_dataset = CortexDatasetCustom(corruption_probabilities=[0, 0], additional_genes=100)

infer = JointSemiSupervisedVariationalInference(svaec, new_gene_dataset, n_labelled_samples_per_class=1)
infer.train(n_epochs=1, lr=0)
print(infer.accuracy('unlabelled'))
infer.show_t_sne('unlabelled', color_by='labels')

infer = JointSemiSupervisedVariationalInferenceUncertain(uvae, new_gene_dataset, n_labelled_samples_per_class=10)
infer.train(n_epochs=1, lr=0)
print(infer.accuracy('unlabelled'))
infer.show_t_sne('unlabelled', color_by='labels')
# Out:
# File data/expression.bin already downloaded
# Preprocessing Cortex data
# Finished preprocessing Cortex data
# training: 100%|██████████| 150/150 [00:09<00:00, 16.27it/s]
# 0.5239616613418531
# training: 100%|██████████| 150/150 [00:10<00:00, 14.72it/s]
# 0.7124600638977636
# File data/expression.bin already downloaded
# Preprocessing Cortex data
# Finished preprocessing Cortex data
# training: 100%|██████████| 1/1 [00:00<00:00, 14.84it/s]
# 0.4622356495468278
# training: 100%|██████████| 1/1 [00:00<00:00, 12.25it/s]
# 0.7188498402555911

# %%
# Corruption probabilities: [0.2, 0.45]

# Corrupted dataset to train
gene_dataset = CortexDatasetCustom(corruption_probabilities=[0.2, 0.45], additional_genes=100)
use_batches=False
use_cuda=True

svaec = SVAEC(gene_dataset.nb_genes, gene_dataset.n_batches, gene_dataset.n_labels)
infer = JointSemiSupervisedVariationalInference(svaec, gene_dataset, n_labelled_samples_per_class=10)
infer.train(n_epochs=150)
print(infer.accuracy('unlabelled'))

uvae = UVAE(gene_dataset.nb_genes, gene_dataset.n_batches, gene_dataset.n_labels)
infer = JointSemiSupervisedVariationalInferenceUncertain(uvae, gene_dataset, n_labelled_samples_per_class=10, classification_ratio=[1.6, 0.85])
infer.train(n_epochs=150)
infer.show_t_sne('all', color_by='labels')
print(infer.accuracy('unlabelled'))

# Uncorrupted dataset to test
new_gene_dataset = CortexDatasetCustom(corruption_probabilities=[0, 0], additional_genes=100)

infer = JointSemiSupervisedVariationalInference(svaec, new_gene_dataset, n_labelled_samples_per_class=1)
infer.train(n_epochs=1, lr=0)
print(infer.accuracy('unlabelled'))
infer.show_t_sne('unlabelled', color_by='labels')

infer = JointSemiSupervisedVariationalInferenceUncertain(uvae, new_gene_dataset, n_labelled_samples_per_class=10)
infer.train(n_epochs=1, lr=0)
print(infer.accuracy('unlabelled'))
infer.show_t_sne('unlabelled', color_by='labels')
# Out:
# File data/expression.bin already downloaded
# Preprocessing Cortex data
# Finished preprocessing Cortex data
# training: 100%|██████████| 150/150 [00:12<00:00, 11.95it/s]
# 0.5463258785942492
# training: 100%|██████████| 150/150 [00:11<00:00, 13.36it/s]
# 0.7028753993610224
# File data/expression.bin already downloaded
# Preprocessing Cortex data
# Finished preprocessing Cortex data
# training: 100%|██████████| 1/1 [00:00<00:00, 13.05it/s]
# 0.525679758308157
# training: 100%|██████████| 1/1 [00:00<00:00, 12.63it/s]
# 0.7188498402555911

# %%
# Corruption probabilities: [0.2, 0.5]

# Corrupted dataset to train
gene_dataset = CortexDatasetCustom(corruption_probabilities=[0.2, 0.5], additional_genes=100)
use_batches=False
use_cuda=True

svaec = SVAEC(gene_dataset.nb_genes, gene_dataset.n_batches, gene_dataset.n_labels)
infer = JointSemiSupervisedVariationalInference(svaec, gene_dataset, n_labelled_samples_per_class=10)
infer.train(n_epochs=150)
print(infer.accuracy('unlabelled'))

uvae = UVAE(gene_dataset.nb_genes, gene_dataset.n_batches, gene_dataset.n_labels)
infer = JointSemiSupervisedVariationalInferenceUncertain(uvae, gene_dataset, n_labelled_samples_per_class=10, classification_ratio=[1.6, 0.8])
infer.train(n_epochs=150)
infer.show_t_sne('all', color_by='labels')
print(infer.accuracy('unlabelled'))

# Uncorrupted dataset to test
new_gene_dataset = CortexDatasetCustom(corruption_probabilities=[0, 0], additional_genes=100)

infer = JointSemiSupervisedVariationalInference(svaec, new_gene_dataset, n_labelled_samples_per_class=1)
infer.train(n_epochs=1, lr=0)
print(infer.accuracy('unlabelled'))
infer.show_t_sne('unlabelled', color_by='labels')

infer = JointSemiSupervisedVariationalInferenceUncertain(uvae, new_gene_dataset, n_labelled_samples_per_class=10)
infer.train(n_epochs=1, lr=0)
print(infer.accuracy('unlabelled'))
infer.show_t_sne('unlabelled', color_by='labels')
# Out:
# File data/expression.bin already downloaded
# Preprocessing Cortex data
# Finished preprocessing Cortex data
# training: 100%|██████████| 150/150 [00:09<00:00, 16.20it/s]
# 0.6006389776357828
# training: 100%|██████████| 150/150 [00:10<00:00, 14.82it/s]
# 0.7284345047923323
# File data/expression.bin already downloaded
# Preprocessing Cortex data
# Finished preprocessing Cortex data
# training: 100%|██████████| 1/1 [00:00<00:00, 15.12it/s]
# 0.31419939577039274
# training: 100%|██████████| 1/1 [00:00<00:00, 13.57it/s]
# 0.7188498402555911
